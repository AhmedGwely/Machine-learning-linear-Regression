# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# header=None: This parameter specifies that there are no headers present in the CSV file. If you have a CSV file without headers, you use header=None to prevent pandas from considering the first row as the header row.

# %%
path = "F:\Work\machine learning\data_multivariables_reg.txt"
data_frame = pd.read_csv(path,header=None, names=["Size","Rooms","Prize"])
data_frame.head()
# Out:
#    Size  Rooms   Prize
# 0  2104      3  399900
# 1  1600      3  329900
# 2  2400      3  369000
# 3  1416      2  232000
# 4  3000      4  539900

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Size    47 non-null     int64
#  1   Rooms   47 non-null     int64
#  2   Prize   47 non-null     int64
# dtypes: int64(3)
# memory usage: 1.2 KB

# %%
data_frame.describe()
# Out:
#               Size      Rooms          Prize
# count    47.000000  47.000000      47.000000
# mean   2000.680851   3.170213  340412.659574
# std     794.702354   0.760982  125039.899586
# min     852.000000   1.000000  169900.000000
# 25%    1432.000000   3.000000  249900.000000
# 50%    1888.000000   3.000000  299900.000000
# 75%    2269.000000   4.000000  384450.000000
# max    4478.000000   5.000000  699900.000000

# %%
df = data_frame.copy()

# %%
df.mean()
# Out:
# Size       2000.680851
# Rooms         3.170213
# Prize    340412.659574
# dtype: float64

# %%
df.std()
# Out:
# Size        794.702354
# Rooms         0.760982
# Prize    125039.899586
# dtype: float64

# %% [raw]
# ############## Rescaling the data to minimizing processing time  ##############
# ####### df = (df - df.mean()) / df.std()
# #### make all data in rang of (-1,1)  exept some big numbers can be grater than 1

# %%
df = (df - df.mean()) / df.std()
df
# Out:
#         Size     Rooms     Prize
# 0   0.130010 -0.223675  0.475747
# 1  -0.504190 -0.223675 -0.084074
# 2   0.502476 -0.223675  0.228626
# 3  -0.735723 -1.537767 -0.867025
# 4   1.257476  1.090417  1.595389
# 5  -0.019732  1.090417 -0.323998
# 6  -0.587240 -0.223675 -0.204036
# 7  -0.721881 -0.223675 -1.130948
# 8  -0.781023 -0.223675 -1.026973
# 9  -0.637573 -0.223675 -0.783051
# 10 -0.076357  1.090417 -0.803053
# 11 -0.000857 -0.223675  0.052682
# 12 -0.139273 -0.223675 -0.083283
# 13  3.117292  2.404508  2.874981
# 14 -0.921956 -0.223675 -0.643896
# 15  0.376643  1.090417  0.875619
# 16 -0.856523 -1.537767 -0.323998
# 17 -0.962223 -0.223675 -1.123743
# 18  0.765468  1.090417  1.276275
# 19  1.296484  1.090417  2.068039
# 20 -0.294048 -0.223675 -0.699878
# 21 -0.141790 -1.537767 -0.683083
# 22 -0.499157 -0.223675 -0.779852
# 23 -0.048673  1.090417 -0.643896
# 24  2.377392 -0.223675  1.867303
# 25 -1.133356 -0.223675 -0.723870
# 26 -0.682873 -0.223675  0.992382
# ...

# %%
df.insert(0,"Ones",1)

# %%
df
# Out:
#     Ones      Size     Rooms     Prize
# 0      1  0.130010 -0.223675  0.475747
# 1      1 -0.504190 -0.223675 -0.084074
# 2      1  0.502476 -0.223675  0.228626
# 3      1 -0.735723 -1.537767 -0.867025
# 4      1  1.257476  1.090417  1.595389
# 5      1 -0.019732  1.090417 -0.323998
# 6      1 -0.587240 -0.223675 -0.204036
# 7      1 -0.721881 -0.223675 -1.130948
# 8      1 -0.781023 -0.223675 -1.026973
# 9      1 -0.637573 -0.223675 -0.783051
# 10     1 -0.076357  1.090417 -0.803053
# 11     1 -0.000857 -0.223675  0.052682
# 12     1 -0.139273 -0.223675 -0.083283
# 13     1  3.117292  2.404508  2.874981
# 14     1 -0.921956 -0.223675 -0.643896
# 15     1  0.376643  1.090417  0.875619
# 16     1 -0.856523 -1.537767 -0.323998
# 17     1 -0.962223 -0.223675 -1.123743
# 18     1  0.765468  1.090417  1.276275
# 19     1  1.296484  1.090417  2.068039
# 20     1 -0.294048 -0.223675 -0.699878
# 21     1 -0.141790 -1.537767 -0.683083
# 22     1 -0.499157 -0.223675 -0.779852
# ...

# %% [raw]
# ############## all features in data frame who are represent x  ##############
# df.shape   >>>> (rows, columns )
# df.shape[1] = the number of columns in data frame

# %%
## - 1 here to take all x feature columns and leave the y columns 
x_columns = df.iloc[ : ,0:df.shape[1]-1] 
# all features in data frame who are represent x
x_columns
# Out:
#     Ones      Size     Rooms
# 0      1  0.130010 -0.223675
# 1      1 -0.504190 -0.223675
# 2      1  0.502476 -0.223675
# 3      1 -0.735723 -1.537767
# 4      1  1.257476  1.090417
# 5      1 -0.019732  1.090417
# 6      1 -0.587240 -0.223675
# 7      1 -0.721881 -0.223675
# 8      1 -0.781023 -0.223675
# 9      1 -0.637573 -0.223675
# 10     1 -0.076357  1.090417
# 11     1 -0.000857 -0.223675
# 12     1 -0.139273 -0.223675
# 13     1  3.117292  2.404508
# 14     1 -0.921956 -0.223675
# 15     1  0.376643  1.090417
# 16     1 -0.856523 -1.537767
# 17     1 -0.962223 -0.223675
# 18     1  0.765468  1.090417
# 19     1  1.296484  1.090417
# 20     1 -0.294048 -0.223675
# 21     1 -0.141790 -1.537767
# 22     1 -0.499157 -0.223675
# 23     1 -0.048673  1.090417
# 24     1  2.377392 -0.223675
# 25     1 -1.133356 -0.223675
# 26     1 -0.682873 -0.223675
# 27     1  0.661026 -0.223675
# 28     1  0.250810 -0.223675
# 29     1  0.800701 -0.223675
# 30     1 -0.203448 -1.537767
# ...

# %% [raw]
# # to take the last column which represent  y

# %%
# to take the last column which represent  y 
y_column = df.iloc[ : ,df.shape[1]-1 : df.shape[1] ]
y_column
# Out:
#        Prize
# 0   0.475747
# 1  -0.084074
# 2   0.228626
# 3  -0.867025
# 4   1.595389
# 5  -0.323998
# 6  -0.204036
# 7  -1.130948
# 8  -1.026973
# 9  -0.783051
# 10 -0.803053
# 11  0.052682
# 12 -0.083283
# 13  2.874981
# 14 -0.643896
# 15  0.875619
# 16 -0.323998
# 17 -1.123743
# 18  1.276275
# 19  2.068039
# 20 -0.699878
# 21 -0.683083
# 22 -0.779852
# 23 -0.643896
# 24  1.867303
# 25 -0.723870
# 26  0.992382
# 27  1.028370
# 28  1.076355
# 29 -0.323998
# 30  0.075875
# 31 -1.363666
# 32 -0.204036
# 33  1.915287
# 34 -0.435962
# 35 -0.723870
# 36 -0.883819
# 37  0.036687
# 38  1.668166
# 39 -0.427165
# 40  0.224627
# 41 -0.084074
# 42 -0.211234
# 43 -0.331196
# 44 -1.283692
# 45 -0.323998
# 46 -0.807044

# %%
X = np.matrix(x_columns) # feature matrix
Y = np.matrix(y_column)  # the target values matrix

# %%
Y[0:10]
# Out:
# matrix([[ 0.47574687],
#         [-0.08407444],
#         [ 0.22862575],
#         [-0.86702453],
#         [ 1.59538948],
#         [-0.32399786],
#         [-0.20403615],
#         [-1.13094828],
#         [-1.02697347],
#         [-0.78305133]])

# %% [raw]
# # theta should have three zeros case i have two x features
# # the law >>>>> theta0 + theta1 * x1 +theta2 * x2

# %%
# the law >>>>> theta0 + theta1 * x1 +theta2 * x2

theta = np.matrix(np.array([0,0,0]))

# %% [raw]
# Cost function

# %%
# theta = [0,0,0]
def cost_fun(x,y,theta):
    z = np.power(( (x * theta.T) - y ),2)
    #print(z)
    return np.sum(z) / (2 * len(x)) , z

cost_fun(X,Y,theta)
# Out:
# (0.4893617021276595,
#  matrix([[2.26335081e-01],
#          [7.06851151e-03],
#          [5.22697321e-02],
#          [7.51731527e-01],
#          [2.54526759e+00],
#          [1.04974612e-01],
#          [4.16307501e-02],
#          [1.27904402e+00],
#          [1.05467451e+00],
#          [6.13169384e-01],
#          [6.44894032e-01],
#          [2.77538338e-03],
#          [6.93600696e-03],
#          [8.26551597e+00],
#          [4.14601733e-01],
#          [7.66709034e-01],
#          [1.04974612e-01],
#          [1.26279739e+00],
#          [1.62887874e+00],
#          [4.27678370e+00],
#          [4.89829044e-01],
#          [4.66602711e-01],
#          [6.08169688e-01],
#          [4.14601733e-01],
#          [3.48681932e+00],
#          [5.23988095e-01],
#          [9.84821951e-01],
#          [1.05754583e+00],
#          [1.15854042e+00],
#          [1.04974612e-01],
#          [5.75694044e-03],
#          [1.85958496e+00],
#          [4.16307501e-02],
# ...

# %% [raw]
# Gradient Descent

# %%
alpha = 0.1
iterations = 1000
def Greadient_Descent(x,y,theta,alpha,iterations):
    temp = np.matrix(np.zeros(theta.shape))
    theta_changers = int(theta.ravel().shape[1]) 
    cost = np.zeros(iterations)
    
    for i in range(iterations):
        error = ((x * theta.T) - y) * 1
        
        for j in range(theta_changers):
            term = np.multiply(error, x[ : ,j ])
            temp[0,j] = theta[0,j] - ( alpha / len(x) * np.sum(term) )
        
        theta = temp
        cost[i],z  = cost_fun(x, y , theta)
    
    return theta , cost



g , cost = Greadient_Descent(X,Y, theta,alpha,iterations)


new_thetas_after_GD = g  # thetas after 1000 iterations

new_thetas_after_GD
# Out:
# matrix([[-1.10963248e-16,  8.84765988e-01, -5.31788197e-02]])

# %%
cost[950:1000]
# Out:
# array([0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648,
#        0.13068648, 0.13068648, 0.13068648, 0.13068648, 0.13068648])

# %%
#last cost after minimize of gradient descent
copute_cosst = cost_fun(X,Y,new_thetas_after_GD)
copute_cosst
# Out:
# (0.13068648053904192,
#  matrix([[1.21678025e-01],
#          [1.22584573e-01],
#          [5.19124473e-02],
#          [8.87196326e-02],
#          [2.92469546e-01],
#          [6.17785098e-02],
#          [9.21965635e-02],
#          [2.54164147e-01],
#          [1.20996581e-01],
#          [5.32885410e-02],
#          [4.59017181e-01],
#          [1.72599841e-03],
#          [7.86625164e-04],
#          [5.99153736e-02],
#          [2.55760240e-02],
#          [3.60438492e-01],
#          [1.23937752e-01],
#          [8.08237700e-02],
#          [4.31652198e-01],
#          [9.58324379e-01],
#          [2.03950466e-01],
#          [4.08843733e-01],
#          [1.22577315e-01],
#          [2.94679750e-01],
#          [6.15178012e-02],
#          [7.12836754e-02],
#          [2.51117920e+00],
#          [1.86297645e-01],
#          [7.09894513e-01],
#          [1.09061648e+00],
#          [3.03115135e-02],
#          [1.60990683e-01],
#          [3.60332548e-02],
# ...

# %%
fig = plt.subplots(figsize=(5,5))
plt.title("Area & Price")
plt.xlabel("Size")
plt.ylabel("prices")
plt.scatter(data_frame.Size,data_frame.Prize)
plt.show()

# %% [raw]
# plt.figure(figsize=(30,20))
# plt.subplot(1,2,1)
# plt.plot(data_frame.Size , data_frame.Prize, marker = "o" ,color="#224499")
# plt.title("my plot")
# plt.xlabel("TOTAL NO. OF PROPERTIES")
# plt.ylabel("AVERAGE SALE PRICE")
#
# plt.subplot(1,2,2)
# plt.bar(data_frame.Rooms , data_frame.Prize,color="#557766")
# plt.title("my plot2")
# plt.xlabel("HIGHEST SALE PRICE")
# plt.ylabel("AVERAGE SALE PRICE")
# plt.show()

# %%
plt.subplot()
plt.bar(data_frame.Rooms , data_frame.Prize,color="#224499")
plt.title("Romes & Price")
plt.xlabel("HIGHEST SALE PRICE")
plt.ylabel("AVERAGE SALE PRICE")
plt.show()

# %% [raw]
# THE BEST FIT LINE EQUATION
# # the law >>>>> theta0 + theta1 * x1 +theta2 * x2

# %%
x_line = np.linspace(df.Size.max(),df.Size.min(),100)
THE_BEST_LINE = new_thetas_after_GD[0,0] + ( new_thetas_after_GD[0,1]  *  x_line)

# %%
THE_BEST_LINE
# Out:
# array([ 2.75807378,  2.71729666,  2.67651954,  2.63574243,  2.59496531,
#         2.55418819,  2.51341107,  2.47263396,  2.43185684,  2.39107972,
#         2.3503026 ,  2.30952548,  2.26874837,  2.22797125,  2.18719413,
#         2.14641701,  2.1056399 ,  2.06486278,  2.02408566,  1.98330854,
#         1.94253143,  1.90175431,  1.86097719,  1.82020007,  1.77942295,
#         1.73864584,  1.69786872,  1.6570916 ,  1.61631448,  1.57553737,
#         1.53476025,  1.49398313,  1.45320601,  1.41242889,  1.37165178,
#         1.33087466,  1.29009754,  1.24932042,  1.20854331,  1.16776619,
#         1.12698907,  1.08621195,  1.04543483,  1.00465772,  0.9638806 ,
#         0.92310348,  0.88232636,  0.84154925,  0.80077213,  0.75999501,
#         0.71921789,  0.67844078,  0.63766366,  0.59688654,  0.55610942,
#         0.5153323 ,  0.47455519,  0.43377807,  0.39300095,  0.35222383,
#         0.31144672,  0.2706696 ,  0.22989248,  0.18911536,  0.14833824,
# ...

# %%
fig = plt.subplots(figsize=(5,5))
plt.title("Best Fit Line")
plt.xlabel("Size")
plt.ylabel("prices")
plt.scatter(df.Size,df.Prize,ls="", label = "prize")
plt.plot(x_line, THE_BEST_LINE,"r", label = "best fit line")
plt.legend(loc = 2)

plt.show()

# %%
plt.subplot()
plt.scatter(df.Rooms , df.Prize,color="#224499")
plt.title("Romes & Price")
plt.xlabel("HIGHEST SALE PRICE")
plt.ylabel("AVERAGE SALE PRICE")
plt.plot(x_line,THE_BEST_LINE,"r")
plt.show()

# %% [raw]
# ERROR PLOTING

# %%
fig = plt.figure(figsize=(5,5))
plt.plot(np.arange(iterations),cost,"r")

# %%
c, z = cost_fun(X,Y,new_thetas_after_GD)
c
# Out:
# 0.13068648053904192

# %%
z.shape
# Out:
# (47, 1)

# %%
x = data_frame.Size
y = data_frame.Rooms
z =data_frame.Prize
X,Y = np.meshgrid(x,y)
y,Z = np.meshgrid(x,z)
fig = plt.figure()
fig2 = plt.figure(figsize=(30,30))
ax = plt.axes(projection='3d')
surf = ax.plot_wireframe(X, Y, Z,cmap='viridis',color = "#224499")
fig.colorbar(surf, shrink=0.5, aspect=5)
